# %% [markdown]
# # Identifying and Recommending Best Restaurants

# %%
# importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing, Understanding, and Inspecting Data :

# %%
# import 1st dataset

BestRestaurants = pd.read_excel('G:\\CAPSTONE PROJECT\\1591617926_data\\data.xlsx')
BestRestaurants.head()
# Out:
#    Restaurant ID              Restaurant Name  Country Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average Cost for two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency Has Table booking Has Online delivery  Price range  \
# 0  Indonesian Rupiah(IDR)                No                  No            3
# 1  Indonesian Rupiah(IDR)                No                  No            3
# 2  Indonesian Rupiah(IDR)                No                  No            3
# 3  Indonesian Rupiah(IDR)                No                  No            3
# 4  Indonesian Rupiah(IDR)                No                  No            3
#
#    Aggregate rating Rating color Rating text  Votes
# 0               4.1        Green   Very Good   1498
# 1               4.6   Dark Green   Excellent    873
# 2               4.9   Dark Green   Excellent    605
# 3               4.2        Green   Very Good    395
# 4               4.3        Green   Very Good    243

# %%
# import 2nd dataset

CountryCode = pd.read_excel('G:\\CAPSTONE PROJECT\\1585743394_datasets_marketing\\Country-Code.xlsx')
CountryCode.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
# merging  both dataset BestRestaurants and CountryCode

BestRestaurants1 = pd.merge(BestRestaurants,CountryCode, on='Country Code', how='left')
BestRestaurants1.head()
# Out:
#    Restaurant ID              Restaurant Name  Country Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average Cost for two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency Has Table booking Has Online delivery  Price range  \
# 0  Indonesian Rupiah(IDR)                No                  No            3
# 1  Indonesian Rupiah(IDR)                No                  No            3
# 2  Indonesian Rupiah(IDR)                No                  No            3
# 3  Indonesian Rupiah(IDR)                No                  No            3
# 4  Indonesian Rupiah(IDR)                No                  No            3
#
#    Aggregate rating Rating color Rating text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
# 1               4.6   Dark Green   Excellent    873  Indonesia
# 2               4.9   Dark Green   Excellent    605  Indonesia
# 3               4.2        Green   Very Good    395  Indonesia
# 4               4.3        Green   Very Good    243  Indonesia

# %% [markdown]
# ##

# %% [markdown]
# ### Perform preliminary data inspection and report the findings as the structure of the data, missing values

# %%
# check for the structure of the data

BestRestaurants1.info()

# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 20 columns):
 #   Column                Non-Null Count  Dtype  
#---  ------                --------------  -----  
# 0   Restaurant ID         9551 non-null   int64  ----  Numeric (discrete)
# 1   Restaurant Name       9550 non-null   object  ----  Categorical 
# 2   Country Code          9551 non-null   int64   ----  Numeric (discrete)
# 3   City                  9551 non-null   object   ----  Categorical
# 4   Address               9551 non-null   object  ----  Categorical
# 5   Locality              9551 non-null   object  ----  Categorical
# 6   Locality Verbose      9551 non-null   object   ----  Categorical
# 7   Longitude             9551 non-null   float64  ----  Numeric (continuous)
# 8   Latitude              9551 non-null   float64  ----  Numeric (continuous)
# 9   Cuisines              9542 non-null   object   ----  Categorical
# 10  Average Cost for two  9551 non-null   int64   ----  Numeric  (continuous)
# 11  Currency              9551 non-null   object   ----  Categorical
# 12  Has Table booking     9551 non-null   object  ----  Categorical
# 13  Has Online delivery   9551 non-null   object  ----  Categorical
# 14  Price range           9551 non-null   int64   ----  Numeric  (discrete)
# 15  Aggregate rating      9551 non-null   float64  ----  Numeric (ordinal)
# 16  Rating color          9551 non-null   object   ----  Categorical
# 17  Rating text           9551 non-null   object   ----  Categorical
# 18  Votes                 9551 non-null   int64   ----  Numeric  (discrete)
# 19  Country               9551 non-null   object   ----  Categorical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9550 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Price range           9551 non-null   int64
#  15  Aggregate rating      9551 non-null   float64
#  16  Rating color          9551 non-null   object
#  17  Rating text           9551 non-null   object
#  18  Votes                 9551 non-null   int64
#  19  Country               9551 non-null   object
# dtypes: float64(3), int64(5), object(12)
# memory usage: 1.5+ MB

# %%
# Replacing spaces between name of the columns with '_' 

BestRestaurants1.columns = BestRestaurants1.columns.str.replace(' ','_')
BestRestaurants1.columns
# Out:
# Index(['Restaurant_ID', 'Restaurant_Name', 'Country_Code', 'City', 'Address',
#        'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Price_range', 'Aggregate_rating',
#        'Rating_color', 'Rating_text', 'Votes', 'Country'],
#       dtype='object')

# %%
# getting rows and columns using 'shape' function

BestRestaurants1.shape

#          Rows   Columns
# We have ((9551, 20))
# Out:
# (9551, 20)

# %%
# Check for the missing values

BestRestaurants1.isna().sum()

# Restaurant_Name         1
# Cuisines                9
# Out:
# Restaurant_ID           0
# Restaurant_Name         1
# Country_Code            0
# City                    0
# Address                 0
# Locality                0
# Locality_Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average_Cost_for_two    0
# Currency                0
# Has_Table_booking       0
# Has_Online_delivery     0
# Price_range             0
# Aggregate_rating        0
# Rating_color            0
# Rating_text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
# finding the record whose has missing value

BestRestaurants1[BestRestaurants1['Restaurant_Name'].isnull()]
# Out:
#       Restaurant_ID Restaurant_Name  Country_Code       City  \
# 1646         113702             NaN             1  Ahmedabad
#
#                                           Address  Locality  \
# 1646  Opposite Sindhu Bhawan, Bodakdev, Ahmedabad  Bodakdev
#
#          Locality_Verbose  Longitude   Latitude  \
# 1646  Bodakdev, Ahmedabad  72.501764  23.040163
#
#                                          Cuisines  Average_Cost_for_two  \
# 1646  North Indian, Continental, Mexican, Italian                   800
#
#                 Currency Has_Table_booking Has_Online_delivery  Price_range  \
# 1646  Indian Rupees(Rs.)                No                  No            3
#
#       Aggregate_rating Rating_color Rating_text  Votes Country
# 1646               4.1        Green   Very Good    769   India

# %%
# Find  MODE  of the this column

BestRestaurants1['Restaurant_Name'].mode()

# 0    Cafe Coffee Day
# Out:
# 0    Cafe Coffee Day
# dtype: object

# %%
# 'Restaurant_Name' has 1 missing value, it is an object datatype column, 
# so we fill that missing value with  MODE

BestRestaurants1['Restaurant_Name'].fillna('Cafe Coffee Day', inplace=True)

# we have successfully replace  MODE value with that null value
# Restaurant_Name         0

# %%
# Find  MODE  of the this column

BestRestaurants1['Cuisines'].mode()
# Out:
# 0    North Indian
# dtype: object

# %%
# # finding the record whose has missing value

BestRestaurants1[BestRestaurants1['Cuisines'].isnull()]
# Out:
#       Restaurant_ID                 Restaurant_Name  Country_Code  \
# 9083       17374552                  Corkscrew Cafe           216
# 9086       17501439                        Dovetail           216
# 9094       17059060                       Hillstone           216
# 9406       17284158               Jimmie's Hot Dogs           216
# 9494       17142698                Leonard's Bakery           216
# 9504       17616465        Tybee Island Social Club           216
# 9533       17284105                   Cookie Shoppe           216
# 9535       17284211  Pearly's Famous Country Cookng           216
# 9539       17606621            HI Lite Bar & Lounge           216
#
#                 City                                          Address  \
# 9083     Gainesville                51 W Main St, Dahlonega, GA 30533
# 9086           Macon                   543 Cherry St, Macon, GA 31201
# 9094         Orlando  215 South Orlando Avenue, Winter Park, FL 32789
# 9406          Albany               204 S Jackson St, Albany, GA 31701
# 9494  Rest of Hawaii             933 Kapahulu Ave, Honolulu, HI 96816
# 9504        Savannah          1311 Butler Ave, Tybee Island, GA 31328
# 9533          Albany               115 N Jackson St, Albany, GA 31701
# 9535          Albany             814 N Slappey Blvd, Albany, GA 31701
# 9539          Miller             109 N Broadway Ave, Miller, SD 57362
#
#           Locality         Locality_Verbose   Longitude   Latitude Cuisines  \
# 9083     Dahlonega   Dahlonega, Gainesville  -83.985800  34.531800      NaN
# 9086         Macon             Macon, Macon  -83.627979  32.836410      NaN
# 9094   Winter Park     Winter Park, Orlando  -81.365260  28.596682      NaN
# 9406        Albany           Albany, Albany  -84.153400  31.575100      NaN
# 9494       Kaimuki  Kaimuki, Rest of Hawaii -157.813432  21.284586      NaN
# 9504  Tybee Island   Tybee Island, Savannah  -80.848297  31.995810      NaN
# 9533        Albany           Albany, Albany  -84.154000  31.577200      NaN
# 9535        Albany           Albany, Albany  -84.175900  31.588200      NaN
# 9539        Miller           Miller, Miller  -98.989100  44.515800      NaN
#
#       Average_Cost_for_two   Currency Has_Table_booking Has_Online_delivery  \
# 9083                    40  Dollar($)                No                  No
# 9086                    40  Dollar($)                No                  No
# 9094                    40  Dollar($)                No                  No
# 9406                    10  Dollar($)                No                  No
# 9494                    10  Dollar($)                No                  No
# 9504                    10  Dollar($)                No                  No
# 9533                     0  Dollar($)                No                  No
# 9535                     0  Dollar($)                No                  No
# 9539                     0  Dollar($)                No                  No
#
#       Price_range  Aggregate_rating Rating_color Rating_text  Votes  \
# 9083            3               3.9       Yellow        Good    209
# 9086            3               3.8       Yellow        Good    102
# 9094            3               4.4        Green   Very Good   1158
# 9406            1               3.9       Yellow        Good    160
# 9494            1               4.7   Dark Green   Excellent    707
# 9504            1               3.9       Yellow        Good    309
# 9533            1               3.4       Orange     Average     34
# 9535            1               3.4       Orange     Average     36
# 9539            1               3.4       Orange     Average     11
#
#             Country
# 9083  United States
# 9086  United States
# 9094  United States
# 9406  United States
# 9494  United States
# 9504  United States
# 9533  United States
# 9535  United States
# 9539  United States

# %%
# 'Cuisines' has 9 missing value, it is an object datatype column, 
# so we fill that missing value with  MODE

BestRestaurants1['Cuisines'].fillna('North Indian', inplace=True)

# we have successfully replace  MODE value with that null value
# Cuisines                0

# %%
BestRestaurants1.isna().sum()
# Out:
# Restaurant_ID           0
# Restaurant_Name         0
# Country_Code            0
# City                    0
# Address                 0
# Locality                0
# Locality_Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average_Cost_for_two    0
# Currency                0
# Has_Table_booking       0
# Has_Online_delivery     0
# Price_range             0
# Aggregate_rating        0
# Rating_color            0
# Rating_text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
BestRestaurants1['Cuisines'].mode()
# Out:
# 0    North Indian
# dtype: object

# %% [markdown]
# ### Based on the findings from the previous questions, identify duplicates and remove them

# %%
BestRestaurants1[BestRestaurants1.duplicated()]

# We have no duplicate records present in our dataset
# Out:
# Empty DataFrame
# Columns: [Restaurant_ID, Restaurant_Name, Country_Code, City, Address, Locality, Locality_Verbose, Longitude, Latitude, Cuisines, Average_Cost_for_two, Currency, Has_Table_booking, Has_Online_delivery, Price_range, Aggregate_rating, Rating_color, Rating_text, Votes, Country]
# Index: []

# %% [markdown]
# ## Performing EDA :

# %% [markdown]
# ### Explore the geographical distribution of the restaurants

# %%
# Country wise Restaurants distribution

country_rest = BestRestaurants1.groupby(['Country_Code','Country'])['Restaurant_ID'].count()
country_rest.nlargest(20)

# we found that India has highest no of restaurants  is 8652 
#               USA has 2nd highest no of restaurants is 434
#               Canada has least no of restaurants is 4
# Out:
# Country_Code  Country
# 1             India             8652
# 216           United States      434
# 215           United Kingdom      80
# 30            Brazil              60
# 189           South Africa        60
# 214           UAE                 60
# 148           New Zealand         40
# 208           Turkey              34
# 14            Australia           24
# 162           Phillipines         22
# 94            Indonesia           21
# 166           Qatar               20
# 184           Singapore           20
# 191           Sri Lanka           20
# 37            Canada               4
# Name: Restaurant_ID, dtype: int64

# %%
# visualization of the above distribution

country_rest.plot(kind='barh')

#Here we can see that India which has highest no of restaurants at the bottom and 2nd highest USA at the top
# Out:
# <AxesSubplot:ylabel='Country_Code,Country'>

# %% [markdown]
# ###  identify the cities with the maximum and minimum number of restaurants

# %%
# Citi wise Restaurants distribution

citi_rest = BestRestaurants1.groupby(['Country','City']).agg(Count = ('Restaurant_ID','count'))
citi_rest
# Out:
#                               Count
# Country       City
# Australia     Armidale            1
#               Balingup            1
#               Beechworth          1
#               Dicky Beach         1
#               East Ballina        1
# ...                             ...
# United States Valdosta           20
#               Vernonia            1
#               Waterloo           20
#               Weirton             1
#               Winchester Bay      1
#
# [141 rows x 1 columns]

# %%
citi_rest.sort_values(by='Count', ascending=False)

# We found New Delhi has highest no of Restaurants is 5473
#          Gurgaon has 2nd highest no of Restaurants is 1118


# MAXIMUM NO OF RESTAURANTS OF EACH CITY:- 

# New Delhi	5473
# Gurgaon	1118
# Noida	1080
# Faridabad	251
# Ghaziabad	25
# Out:
#                               Count
# Country       City
# India         New Delhi        5473
#               Gurgaon          1118
#               Noida            1080
#               Faridabad         251
#               Ghaziabad          25
# ...                             ...
#               Panchkula           1
# Australia     Balingup            1
# Indonesia     Bandung             1
# Phillipines   Quezon City         1
# United States Winchester Bay      1
#
# [141 rows x 1 columns]

# %%
citi_rest.sort_values(by='Count', ascending=True)

# MINIMUM NO OF RESTAURANTS OF EACH CITY:-

#Australia	Armidale	1
#Canada 	Vineland Station	1
#           Yorkton	1
#India	Mohali	1
#       Panchkula	1
# Out:
#                             Count
# Country   City
# Australia Armidale              1
# Canada    Vineland Station      1
#           Yorkton               1
# India     Mohali                1
#           Panchkula             1
# ...                           ...
#           Ghaziabad            25
#           Faridabad           251
#           Noida              1080
#           Gurgaon            1118
#           New Delhi          5473
#
# [141 rows x 1 columns]

# %% [markdown]
# ###

# %% [markdown]
# ### Restaurant franchising is a thriving venture. So, it is very important to explore the franchise with most national presence

# %%
BestRestaurants1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average_Cost_for_two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indonesian Rupiah(IDR)                No                  No            3
# 1  Indonesian Rupiah(IDR)                No                  No            3
# 2  Indonesian Rupiah(IDR)                No                  No            3
# 3  Indonesian Rupiah(IDR)                No                  No            3
# 4  Indonesian Rupiah(IDR)                No                  No            3
#
#    Aggregate_rating Rating_color Rating_text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
# 1               4.6   Dark Green   Excellent    873  Indonesia
# 2               4.9   Dark Green   Excellent    605  Indonesia
# 3               4.2        Green   Very Good    395  Indonesia
# 4               4.3        Green   Very Good    243  Indonesia

# %%
BestRestaurants1.groupby(['Restaurant_Name','Country'])['Country'].count().nlargest(10) 

# following countries has most no of restaurants

# Restaurant_Name   Country
#Cafe Coffee Day   India      84
#Domino's Pizza    India      79
#Subway            India      63
#Green Chick Chop  India      51
#McDonald's        India      48
#Keventers         India      34
#Giani             India      29
#Pizza Hut         India      29
#Baskin Robbins    India      28
#Barbeque Nation   India      25
# Out:
# Restaurant_Name   Country
# Cafe Coffee Day   India      84
# Domino's Pizza    India      79
# Subway            India      63
# Green Chick Chop  India      51
# McDonald's        India      48
# Keventers         India      34
# Giani             India      29
# Pizza Hut         India      29
# Baskin Robbins    India      28
# Barbeque Nation   India      25
# Name: Country, dtype: int64

# %%
len(BestRestaurants1['Restaurant_Name'].unique())
# Out:
# 7445

# %%
len(BestRestaurants1['Restaurant_ID'].unique())
# Out:
# 9551

# %%
BestRestaurants1['Country'].unique()
# Out:
# array(['Indonesia', 'India', 'Phillipines', 'Sri Lanka', 'South Africa',
#        'Qatar', 'Singapore', 'UAE', 'Brazil', 'Turkey', 'United Kingdom',
#        'New Zealand', 'Australia', 'United States', 'Canada'],
#       dtype=object)

# %% [markdown]
# ###

# %% [markdown]
# ### Find out the ratio between restaurants that allow table booking vs. those that do not allow table booking

# %%
BestRestaurants1['Has_Table_booking'].replace(['No','Yes'],[0,1], inplace=True)

# %%
BestRestaurants1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average_Cost_for_two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency  Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indonesian Rupiah(IDR)                  0                  No            3
# 1  Indonesian Rupiah(IDR)                  0                  No            3
# 2  Indonesian Rupiah(IDR)                  0                  No            3
# 3  Indonesian Rupiah(IDR)                  0                  No            3
# 4  Indonesian Rupiah(IDR)                  0                  No            3
#
#    Aggregate_rating Rating_color Rating_text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
# 1               4.6   Dark Green   Excellent    873  Indonesia
# 2               4.9   Dark Green   Excellent    605  Indonesia
# 3               4.2        Green   Very Good    395  Indonesia
# 4               4.3        Green   Very Good    243  Indonesia

# %%
BestRestaurants1[BestRestaurants1['Has_Table_booking']==0]
# Out:
#       Restaurant_ID                Restaurant_Name  Country_Code      City  \
# 0           7402935                           Skye            94   Jakarta
# 1           7410290       Satoo - Hotel Shangri-La            94   Jakarta
# 2           7420899                     Sushi Masa            94   Jakarta
# 3           7421967                 3 Wise Monkeys            94   Jakarta
# 4           7422489    Avec Moi Restaurant and Bar            94   Jakarta
# ...             ...                            ...           ...       ...
# 9546       18279289           BMG - All Day Dining             1  Dehradun
# 9547        2300497  Atmosphere Grill Cafe Sheesha             1    Kanpur
# 9548       18312106                     UrbanCrave             1    Kanpur
# 9549        3900245             Deena Chat Bhandar             1  Varanasi
# 9550       18246202                VNS Live Studio             1  Varanasi
#
#                                                 Address  \
# 0     Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1                  Hotel Shangri-La, Jl. Jend. Sudirman
# 2                      Jl. Tuna Raya No. 5, Penjaringan
# 3                   Jl. Suryo No. 26, Senopati, Jakarta
# 4     Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
# ...                                                 ...
# 9546               140 A, Rajpur Road, Jakhan, Dehradun
# 9547  8th Floor, J.S. Tower, 16/106 - Mall Road, Kan...
# 9548  14/125, The Mall, Mall Road, Colonelganj, Para...
# 9549    D-47/184, Luxa Road, Dashaswmedh Road, Varanasi
# 9550  Hotel Varuna Ground Floor, 22 Gulab Bagh, Sigr...
#
#                            Locality                        Locality_Verbose  \
# 0     Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1        Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                       Penjaringan                    Penjaringan, Jakarta
# 3                          Senopati                       Senopati, Jakarta
# 4                           Thamrin                        Thamrin, Jakarta
# ...                             ...                                     ...
# 9546                         Jakhan                        Jakhan, Dehradun
# 9547                      Mall Road                       Mall Road, Kanpur
# 9548                         Parade                          Parade, Kanpur
# 9549               Dashaswmedh Road              Dashaswmedh Road, Varanasi
# 9550                          Sigra                         Sigra, Varanasi
#
#        Longitude   Latitude  \
# 0     106.821999  -6.196778
# 1     106.818961  -6.203292
# 2     106.800144  -6.101298
# 3     106.813400  -6.235241
# 4     106.821023  -6.196270
# ...          ...        ...
# 9546   78.068890  30.362686
# 9547   80.354002  26.472001
# 9548   80.342796  26.474986
# 9549    0.000000   0.000000
# 9550   82.991694  25.318345
#
#                                                Cuisines  Average_Cost_for_two  \
# 0                                  Italian, Continental                800000
# 1                            Asian, Indonesian, Western                800000
# 2                                       Sushi, Japanese                500000
# 3                                              Japanese                450000
# 4                                       French, Western                350000
# ...                                                 ...                   ...
# 9546                   Chinese, North Indian, Fast Food                     0
# 9547                       Indian, Chinese, Continental                     0
# 9548  Cafe, Continental, Desserts, Ice Cream, Italia...                     0
# 9549                                        Street Food                     0
# 9550                              Chinese, North Indian                     0
#
#                     Currency  Has_Table_booking Has_Online_delivery  \
# 0     Indonesian Rupiah(IDR)                  0                  No
# 1     Indonesian Rupiah(IDR)                  0                  No
# 2     Indonesian Rupiah(IDR)                  0                  No
# 3     Indonesian Rupiah(IDR)                  0                  No
# 4     Indonesian Rupiah(IDR)                  0                  No
# ...                      ...                ...                 ...
# 9546      Indian Rupees(Rs.)                  0                  No
# 9547      Indian Rupees(Rs.)                  0                  No
# 9548      Indian Rupees(Rs.)                  0                  No
# 9549      Indian Rupees(Rs.)                  0                  No
# 9550      Indian Rupees(Rs.)                  0                  No
#
#       Price_range  Aggregate_rating Rating_color Rating_text  Votes    Country
# 0               3               4.1        Green   Very Good   1498  Indonesia
# 1               3               4.6   Dark Green   Excellent    873  Indonesia
# 2               3               4.9   Dark Green   Excellent    605  Indonesia
# 3               3               4.2        Green   Very Good    395  Indonesia
# 4               3               4.3        Green   Very Good    243  Indonesia
# ...           ...               ...          ...         ...    ...        ...
# 9546            1               4.3        Green   Very Good     63      India
# 9547            1               3.6       Yellow        Good     34      India
# 9548            1               3.9       Yellow        Good    127      India
# 9549            1               3.8       Yellow        Good     78      India
# 9550            1               3.5       Yellow        Good    109      India
#
# [8393 rows x 20 columns]

# %%
BestRestaurants1[BestRestaurants1['Has_Table_booking']==1]
# Out:
#       Restaurant_ID                             Restaurant_Name  Country_Code  \
# 21             2701           Orient Express - Taj Palace Hotel             1
# 24          6300010    Spiral - Sofitel Philippine Plaza Manila           162
# 25           301523  Nostalgia at 1911 Brasserie - The Imperial             1
# 26             2724                         1911 - The Imperial             1
# 27             2725              The Spice Route - The Imperial             1
# ...             ...                                         ...           ...
# 8973        6801873    Mr Cooper's House & Garden - The Midland           215
# 9020        7601102                                  Chaophraya           215
# 9040        6104220                                   Roti Chai           215
# 9184        6900224                                  Chaophraya           215
# 9191        6100054                                 Masala Zone           215
#
#             City                                            Address  \
# 21     New Delhi  Taj Palace Hotel, Diplomatic Enclave, Chanakya...
# 24    Pasay City  Plaza Level, Sofitel Philippine Plaza Manila, ...
# 25     New Delhi                   The Imperial, Janpath, New Delhi
# 26     New Delhi                   The Imperial, Janpath, New Delhi
# 27     New Delhi                   The Imperial, Janpath, New Delhi
# ...          ...                                                ...
# 8973  Manchester  The Midland, Peter Street, Deansgate, Manchest...
# 9020   Edinburgh  4th Floor, 33 Castle Street, New Town, Edinbur...
# 9040      London  3 Portman Mews South, Marble Arch, London W1H 6HS
# 9184  Birmingham  Middle Mall, Bullring Shopping Centre, Special...
# 9191      London   48 Floral Street, Covent Garden, London WC2E 9DA
#
#                                          Locality  \
# 21             The Taj Palace Hotel, Chanakyapuri
# 24    Sofitel Philippine Plaza Manila, Pasay City
# 25                          The Imperial, Janpath
# 26                          The Imperial, Janpath
# 27                          The Imperial, Janpath
# ...                                           ...
# 8973                       The Midland, Deansgate
# 9020                                     New Town
# 9040              Portman Mews South, Marble Arch
# 9184          Bullring Shopping Centre, Southside
# 9191                                Covent Garden
#
#                                        Locality_Verbose   Longitude  \
# 21        The Taj Palace Hotel, Chanakyapuri, New Delhi   77.170087
# 24    Sofitel Philippine Plaza Manila, Pasay City, P...  120.980090
# 25                     The Imperial, Janpath, New Delhi   77.218187
# 26                     The Imperial, Janpath, New Delhi   77.218185
# 27                     The Imperial, Janpath, New Delhi   77.218187
# ...                                                 ...         ...
# 8973                 The Midland, Deansgate, Manchester   -2.245034
# 9020                                New Town, Edinburgh   -3.203159
# 9040            Portman Mews South, Marble Arch, London   -0.155732
# 9184    Bullring Shopping Centre, Southside, Birmingham   -1.894286
# 9191                                      Covent Garden   -0.123132
#
#        Latitude                                         Cuisines  \
# 21    28.595008                                         European
# 24    14.552990                          European, Asian, Indian
# 25    28.625445                            European, Continental
# 26    28.625443     North Indian, Chinese, South Indian, Italian
# 27    28.625445  Malaysian, Thai, Kerala, Vietnamese, Sri Lankan
# ...         ...                                              ...
# 8973  53.477358            European, Mediterranean, Contemporary
# 9020  55.952221                                             Thai
# 9040  51.514641                              Indian, Street Food
# 9184  52.477633                                             Thai
# 9191  51.513196                                    Indian, Curry
#
#       Average_Cost_for_two            Currency  Has_Table_booking  \
# 21                    8000  Indian Rupees(Rs.)                  1
# 24                    6000    Botswana Pula(P)                  1
# 25                    6000  Indian Rupees(Rs.)                  1
# 26                    6000  Indian Rupees(Rs.)                  1
# 27                    6000  Indian Rupees(Rs.)                  1
# ...                    ...                 ...                ...
# 8973                    55          Pounds(å£)                  1
# 9020                    50          Pounds(å£)                  1
# 9040                    45          Pounds(å£)                  1
# 9184                    30          Pounds(å£)                  1
# 9191                    30          Pounds(å£)                  1
#
#      Has_Online_delivery  Price_range  Aggregate_rating Rating_color  \
# 21                    No            4               4.0        Green
# 24                    No            4               4.9   Dark Green
# 25                    No            4               3.2       Orange
# 26                    No            4               3.9       Yellow
# 27                    No            4               4.0        Green
# ...                  ...          ...               ...          ...
# 8973                  No            3               4.2        Green
# 9020                  No            4               4.3        Green
# 9040                  No            3               4.5   Dark Green
# 9184                  No            2               3.9       Yellow
# 9191                  No            2               4.1        Green
#
#      Rating_text  Votes         Country
# 21     Very Good    145           India
# 24     Excellent    621     Phillipines
# 25       Average     12           India
# 26          Good    272           India
# 27     Very Good    259           India
# ...          ...    ...             ...
# 8973   Very Good     67  United Kingdom
# 9020   Very Good     61  United Kingdom
# 9040   Excellent    367  United Kingdom
# 9184        Good     22  United Kingdom
# 9191   Very Good    316  United Kingdom
#
# [1158 rows x 20 columns]

# %%
BestRestaurants1[BestRestaurants1['Has_Table_booking']==0].count()
# Out:
# Restaurant_ID           8393
# Restaurant_Name         8393
# Country_Code            8393
# City                    8393
# Address                 8393
# Locality                8393
# Locality_Verbose        8393
# Longitude               8393
# Latitude                8393
# Cuisines                8393
# Average_Cost_for_two    8393
# Currency                8393
# Has_Table_booking       8393
# Has_Online_delivery     8393
# Price_range             8393
# Aggregate_rating        8393
# Rating_color            8393
# Rating_text             8393
# Votes                   8393
# Country                 8393
# dtype: int64

# %%
BestRestaurants1[BestRestaurants1['Has_Table_booking']==1].count()
# Out:
# Restaurant_ID           1158
# Restaurant_Name         1158
# Country_Code            1158
# City                    1158
# Address                 1158
# Locality                1158
# Locality_Verbose        1158
# Longitude               1158
# Latitude                1158
# Cuisines                1158
# Average_Cost_for_two    1158
# Currency                1158
# Has_Table_booking       1158
# Has_Online_delivery     1158
# Price_range             1158
# Aggregate_rating        1158
# Rating_color            1158
# Rating_text             1158
# Votes                   1158
# Country                 1158
# dtype: int64

# %%
Has_table_book = BestRestaurants1[BestRestaurants1['Has_Table_booking']==1]['Restaurant_ID'].count()

Has_not_table_book = BestRestaurants1[BestRestaurants1['Has_Table_booking']==0]['Restaurant_ID'].count()

# %%
print('Ratio between restaurants that allow table booking vs. those that do not allow table booking: ',
      round((Has_table_book/Has_not_table_book),2))

# SO, WE FOUND THAT RATIO B/W TABLE BOOKING AND NON TABLE BOOKING IS 0.14
# Out:
# Ratio between restaurants that allow table booking vs. those that do not allow table booking:  0.14

# %% [markdown]
# ###

# %%
BestRestaurants1['Has_Table_booking'].value_counts()
# Out:
# 0    8393
# 1    1158
# Name: Has_Table_booking, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.set_style(style='whitegrid',)
sns.set(font_scale=1.2)

sns.barplot(list(BestRestaurants1['Has_Table_booking'].value_counts().keys()),
                list(BestRestaurants1['Has_Table_booking'].value_counts()), color='g')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.set_style(style='whitegrid',)
sns.set(font_scale=1.2)
labels = 'Non Table Booking','Table Booking'
colors='#66b3ff','#99ff99'
explode = (0.1,0)
plt.pie(list(BestRestaurants1['Has_Table_booking'].value_counts()),
       labels=labels,
       explode=explode,colors=colors ,autopct='%1.1f%%', shadow=True,startangle=90)
plt.title("Table Booking  VS  Non Table Booking")
plt.show()

# here, Table Booking contains 12.1%  and Non Table Booking contains 87.9% of the whole .
# Most of the Restaurants do not allow table booking.
# They want customer com to their Restaurants and have some food and njoy themselves.

# %% [markdown]
# ###

# %% [markdown]
# ### Find out the percentage of restaurants providing online delivery

# %%
BestRestaurants1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average_Cost_for_two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency  Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indonesian Rupiah(IDR)                  0                  No            3
# 1  Indonesian Rupiah(IDR)                  0                  No            3
# 2  Indonesian Rupiah(IDR)                  0                  No            3
# 3  Indonesian Rupiah(IDR)                  0                  No            3
# 4  Indonesian Rupiah(IDR)                  0                  No            3
#
#    Aggregate_rating Rating_color Rating_text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
# 1               4.6   Dark Green   Excellent    873  Indonesia
# 2               4.9   Dark Green   Excellent    605  Indonesia
# 3               4.2        Green   Very Good    395  Indonesia
# 4               4.3        Green   Very Good    243  Indonesia

# %%
BestRestaurants1['Has_Online_delivery'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
BestRestaurants1['Has_Online_delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has_Online_delivery, dtype: int64

# %%
rest_onlineDl = BestRestaurants1[BestRestaurants1['Has_Online_delivery']=='Yes']['Restaurant_ID'].count()

# %%
rest_not_onlineDl = BestRestaurants1[BestRestaurants1['Has_Online_delivery']=='No']['Restaurant_ID'].count()

# %%
rest_onlineDl
# Out:
# 2451

# %%
rest_not_onlineDl
# Out:
# 7100

# %%
# to get percentaage of how many restaurants has online delivery we do

print("Percentage of Restaurants which has online delivery: {} %".format((round(rest_onlineDl/len(BestRestaurants1),3)*100)))

# WE FOUND THAT ONLY 25.7 % RESTAURANTS HAS ONLINE DELIVERY.
# Out:
# Percentage of Restaurants which has online delivery: 25.7 %

# %% [markdown]
# ###

# %%
# Creating a pie chart for online delivery

plt.figure(figsize=(12,8))
colors = ['g','m']
explode = (0.1,0)
labels = ['Non Online Delivery','Online Delivery']

plt.pie(list(BestRestaurants1['Has_Online_delivery'].value_counts()),
       labels =labels, explode=explode,colors=colors ,autopct='%1.1f%%', shadow=True,startangle=90)
plt.title("Non Online Delivery  VS  Online Delivery")
plt.axis('equal')
plt.show()

# HERE, ONLINE DELIVERY CONTAINS ONLY 25.7 AND NON ONLINE DELIVERY CONTAINS 74.3 OF THE WHOLE.
# MOST OF THE RESTAURANTS DO NOT PREFER ONLINE DELIVERY.
# THEY JUST WANT THAT CUSTOMER VISIT THEIR RESTAURANTS AND HAVE SOME FOODS
# FOR THAT THEY CAN SAVE DELIVERY EXPENCES MONEY AND GAIN MORE PROFIT.

# %% [markdown]
# ---

# %% [markdown]
# ###

# %% [markdown]
# ### Calculate the difference in number of votes for the restaurants that deliver and the restaurants that do not deliver

# %%
BestRestaurants1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average_Cost_for_two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency  Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indonesian Rupiah(IDR)                  0                  No            3
# 1  Indonesian Rupiah(IDR)                  0                  No            3
# 2  Indonesian Rupiah(IDR)                  0                  No            3
# 3  Indonesian Rupiah(IDR)                  0                  No            3
# 4  Indonesian Rupiah(IDR)                  0                  No            3
#
#    Aggregate_rating Rating_color Rating_text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
# 1               4.6   Dark Green   Excellent    873  Indonesia
# 2               4.9   Dark Green   Excellent    605  Indonesia
# 3               4.2        Green   Very Good    395  Indonesia
# 4               4.3        Green   Very Good    243  Indonesia

# %%
BestRestaurants1.groupby(['Votes','Has_Online_delivery']).agg(count=('Votes','count'))
# Out:
#                            count
# Votes Has_Online_delivery
# 0     No                    1070
#       Yes                     24
# 1     No                     464
#       Yes                     19
# 2     No                     297
# ...                          ...
# 6907  No                       1
# 7574  Yes                      1
# 7931  Yes                      1
# 9667  Yes                      1
# 10934 No                       1
#
# [1439 rows x 1 columns]

# %%
rest_dl_votes =BestRestaurants1[BestRestaurants1['Has_Online_delivery']=='Yes']['Votes'].sum()

# %%
rest_not_dl_votes = BestRestaurants1[BestRestaurants1['Has_Online_delivery']=='No']['Votes'].sum()

# %%
BestRestaurants1.groupby(['Has_Online_delivery'])['Votes'].sum()
# Out:
# Has_Online_delivery
# No     980731
# Yes    517914
# Name: Votes, dtype: int64

# %%
print('No. of Votes: that deliver online VS Votes: that do not deliver online: ',(rest_not_dl_votes-rest_dl_votes))
# Out:
# No. of Votes: that deliver online VS Votes: that do not deliver online:  462817

# %% [markdown]
# ###

# %%
# Creating a pie chart for No. of Votes: that deliver online VS Votes: that do not deliver online:

plt.figure(figsize=(12,8))
labels = ['Votes for online delivery','Votes for not online delivery']
sizes = [rest_dl_votes,rest_not_dl_votes]
explode = (0.06,0)
colors='#99ff99','#66b3ff'

plt.pie(sizes, labels=labels, explode=explode, colors=colors, autopct='%0.1f%%', shadow=True)
plt.title('No. of Votes: that deliver online VS Votes: that do not deliver online')
plt.axis('equal')
plt.show()


# ACC. TO OUR FIGURE,
                    # WE CAN CONCLUDE THAT ONLY 34.6% OF VOTES HAS GIVEN FOR ONLINE DELIVERY
                    # AND 65.4% OF VOTES HAS GIVEN FOR NON ONLINE DELIVERY RESTAURANTS

# %% [markdown]
# ---

# %% [markdown]
# ### What are the top 10 cuisines served across cities?

# %%
BestRestaurants1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average_Cost_for_two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency  Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indonesian Rupiah(IDR)                  0                  No            3
# 1  Indonesian Rupiah(IDR)                  0                  No            3
# 2  Indonesian Rupiah(IDR)                  0                  No            3
# 3  Indonesian Rupiah(IDR)                  0                  No            3
# 4  Indonesian Rupiah(IDR)                  0                  No            3
#
#    Aggregate_rating Rating_color Rating_text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
# 1               4.6   Dark Green   Excellent    873  Indonesia
# 2               4.9   Dark Green   Excellent    605  Indonesia
# 3               4.2        Green   Very Good    395  Indonesia
# 4               4.3        Green   Very Good    243  Indonesia

# %%
top_10_Cuisines =BestRestaurants1.groupby(['Cuisines'])['City'].count().nlargest(10)

# %%
top_10_Cuisines

# HERE, TOP 10 CUISINES ACCROSS CITIES AND THEIR COUNTS

#North Indian                      945
#North Indian, Chinese             511
#Chinese                           354
#Fast Food                         354
#North Indian, Mughlai             334
#Cafe                              299
#Bakery                            218
#North Indian, Mughlai, Chinese    197
#Bakery, Desserts                  170
#Street Food                       149
# Out:
# Cuisines
# North Indian                      945
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: City, dtype: int64

# %%
len(BestRestaurants1['Cuisines'].unique())
# Out:
# 1825

# %%
# Spliting the cuisines columns into different cuisines and assign column names

cuisines = BestRestaurants1['Cuisines'].apply(lambda x: pd.Series(x.split(',')))
cuisines.columns = ['Cuisine_1','Cuisine_2','Cuisine_3','Cuisine_4','Cuisine_5','Cuisine_6','Cuisine_7','Cuisine_8']
cuisines
# Out:
#         Cuisine_1      Cuisine_2     Cuisine_3   Cuisine_4 Cuisine_5  \
# 0         Italian    Continental           NaN         NaN       NaN
# 1           Asian     Indonesian       Western         NaN       NaN
# 2           Sushi       Japanese           NaN         NaN       NaN
# 3        Japanese            NaN           NaN         NaN       NaN
# 4          French        Western           NaN         NaN       NaN
# ...           ...            ...           ...         ...       ...
# 9546      Chinese   North Indian     Fast Food         NaN       NaN
# 9547       Indian        Chinese   Continental         NaN       NaN
# 9548         Cafe    Continental      Desserts   Ice Cream   Italian
# 9549  Street Food            NaN           NaN         NaN       NaN
# 9550      Chinese   North Indian           NaN         NaN       NaN
#
#        Cuisine_6 Cuisine_7 Cuisine_8
# 0            NaN       NaN       NaN
# 1            NaN       NaN       NaN
# 2            NaN       NaN       NaN
# 3            NaN       NaN       NaN
# 4            NaN       NaN       NaN
# ...          ...       ...       ...
# 9546         NaN       NaN       NaN
# 9547         NaN       NaN       NaN
# 9548   Beverages       NaN       NaN
# 9549         NaN       NaN       NaN
# 9550         NaN       NaN       NaN
#
# [9551 rows x 8 columns]

# %%
# concatenating cuisines dataframe with our main dataframe

df_cuisines = pd.concat([BestRestaurants1, cuisines], axis=1)
df_cuisines.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  ...  Votes    Country  \
# 0  106.821999 -6.196778        Italian, Continental  ...   1498  Indonesia
# 1  106.818961 -6.203292  Asian, Indonesian, Western  ...    873  Indonesia
# 2  106.800144 -6.101298             Sushi, Japanese  ...    605  Indonesia
# 3  106.813400 -6.235241                    Japanese  ...    395  Indonesia
# 4  106.821023 -6.196270             French, Western  ...    243  Indonesia
#
#    Cuisine_1     Cuisine_2  Cuisine_3  Cuisine_4 Cuisine_5 Cuisine_6  \
# 0    Italian   Continental        NaN        NaN       NaN       NaN
# 1      Asian    Indonesian    Western        NaN       NaN       NaN
# 2      Sushi      Japanese        NaN        NaN       NaN       NaN
# 3   Japanese           NaN        NaN        NaN       NaN       NaN
# 4     French       Western        NaN        NaN       NaN       NaN
#
#    Cuisine_7 Cuisine_8
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN
#
# [5 rows x 28 columns]

# %%
# selecting ['Country','City','Locality_Verbose','Cuisine_1','Cuisine_2','Cuisine_3',
#                                        'Cuisine_4','Cuisine_5','Cuisine_6','Cuisine_7','Cuisine_8']
# columns where we will do further analysis

cuisines_loc = pd.DataFrame(df_cuisines[['Country','City','Locality_Verbose','Cuisine_1','Cuisine_2','Cuisine_3',
                                        'Cuisine_4','Cuisine_5','Cuisine_6','Cuisine_7','Cuisine_8']])

# %%
cuisines_loc
# Out:
#         Country      City                        Locality_Verbose  \
# 0     Indonesia   Jakarta  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Indonesia   Jakarta     Hotel Shangri-La, Sudirman, Jakarta
# 2     Indonesia   Jakarta                    Penjaringan, Jakarta
# 3     Indonesia   Jakarta                       Senopati, Jakarta
# 4     Indonesia   Jakarta                        Thamrin, Jakarta
# ...         ...       ...                                     ...
# 9546      India  Dehradun                        Jakhan, Dehradun
# 9547      India    Kanpur                       Mall Road, Kanpur
# 9548      India    Kanpur                          Parade, Kanpur
# 9549      India  Varanasi              Dashaswmedh Road, Varanasi
# 9550      India  Varanasi                         Sigra, Varanasi
#
#         Cuisine_1      Cuisine_2     Cuisine_3   Cuisine_4 Cuisine_5  \
# 0         Italian    Continental           NaN         NaN       NaN
# 1           Asian     Indonesian       Western         NaN       NaN
# 2           Sushi       Japanese           NaN         NaN       NaN
# 3        Japanese            NaN           NaN         NaN       NaN
# 4          French        Western           NaN         NaN       NaN
# ...           ...            ...           ...         ...       ...
# 9546      Chinese   North Indian     Fast Food         NaN       NaN
# 9547       Indian        Chinese   Continental         NaN       NaN
# 9548         Cafe    Continental      Desserts   Ice Cream   Italian
# 9549  Street Food            NaN           NaN         NaN       NaN
# 9550      Chinese   North Indian           NaN         NaN       NaN
#
#        Cuisine_6 Cuisine_7 Cuisine_8
# 0            NaN       NaN       NaN
# 1            NaN       NaN       NaN
# 2            NaN       NaN       NaN
# 3            NaN       NaN       NaN
# 4            NaN       NaN       NaN
# ...          ...       ...       ...
# 9546         NaN       NaN       NaN
# 9547         NaN       NaN       NaN
# 9548   Beverages       NaN       NaN
# 9549         NaN       NaN       NaN
# 9550         NaN       NaN       NaN
#
# [9551 rows x 11 columns]

# %%
# stacking the columns

cuisines_loc_stacked = pd.DataFrame(cuisines_loc.stack())
cuisines_loc.head()
# Out:
#      Country     City                        Locality_Verbose Cuisine_1  \
# 0  Indonesia  Jakarta  Grand Indonesia Mall, Thamrin, Jakarta   Italian
# 1  Indonesia  Jakarta     Hotel Shangri-La, Sudirman, Jakarta     Asian
# 2  Indonesia  Jakarta                    Penjaringan, Jakarta     Sushi
# 3  Indonesia  Jakarta                       Senopati, Jakarta  Japanese
# 4  Indonesia  Jakarta                        Thamrin, Jakarta    French
#
#       Cuisine_2 Cuisine_3 Cuisine_4 Cuisine_5 Cuisine_6 Cuisine_7 Cuisine_8
# 0   Continental       NaN       NaN       NaN       NaN       NaN       NaN
# 1    Indonesian   Western       NaN       NaN       NaN       NaN       NaN
# 2      Japanese       NaN       NaN       NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       Western       NaN       NaN       NaN       NaN       NaN       NaN

# %%
# Melting the data

keys = [c for c in cuisines_loc  if c.startswith('Cuisine')]

a= pd.melt(cuisines_loc, id_vars='Locality_Verbose', value_vars=keys, value_name='Cuisines')

#melting the stack into one row
max_rate = pd.DataFrame(a.groupby(by=['Locality_Verbose','variable','Cuisines']).size().reset_index())
# find the highest restuarant in the city
max_rate

# we don't need variable column, so we delete that
del max_rate['variable']

# setting the column names
max_rate.columns = ['Locality_Verbose','Cuisines','Count']
max_rate.head()
# Out:
#                                  Locality_Verbose      Cuisines  Count
# 0      ILD Trade Centre Mall, Sohna Road, Gurgaon          Cafe      1
# 1      ILD Trade Centre Mall, Sohna Road, Gurgaon  North Indian      1
# 2      ILD Trade Centre Mall, Sohna Road, Gurgaon     Beverages      1
# 3      ILD Trade Centre Mall, Sohna Road, Gurgaon       Mughlai      1
# 4  12th Square Building, Banjara Hills, Hyderabad       Mughlai      1

# %%
# find the highest restuarant in the city

loc = max_rate.sort_values(by='Count', ascending=False).groupby(['Locality_Verbose'], as_index=False).first()
loc.head()
# Out:
#                                  Locality_Verbose        Cuisines  Count
# 0      ILD Trade Centre Mall, Sohna Road, Gurgaon            Cafe      1
# 1  12th Square Building, Banjara Hills, Hyderabad         Mughlai      1
# 2                 A Hotel, Gurdev Nagar, Ludhiana         Chinese      1
# 3             ARSS Mall, Paschim Vihar, New Delhi    North Indian      1
# 4                           Aaya Nagar, New Delhi  Cuisine Varies      1

# %%
# merging 2 dataframes, loc and BestRestaurants1

Rest = loc.merge(BestRestaurants1, left_on='Locality_Verbose', right_on='Locality_Verbose', how='inner')
Rest.head()
# Out:
#                                  Locality_Verbose    Cuisines_x  Count  \
# 0      ILD Trade Centre Mall, Sohna Road, Gurgaon          Cafe      1
# 1      ILD Trade Centre Mall, Sohna Road, Gurgaon          Cafe      1
# 2  12th Square Building, Banjara Hills, Hyderabad       Mughlai      1
# 3                 A Hotel, Gurdev Nagar, Ludhiana       Chinese      1
# 4             ARSS Mall, Paschim Vihar, New Delhi  North Indian      1
#
#    Restaurant_ID    Restaurant_Name  Country_Code       City  \
# 0       18237941      Pind Balluchi             1    Gurgaon
# 1       18396451              K Lab             1    Gurgaon
# 2          90744            Exotica             1  Hyderabad
# 3          15239  Basant Restaurant             1   Ludhiana
# 4         310281         Haldiram's             1  New Delhi
#
#                                              Address  \
# 0  112/112-A, 1st Floor, ILD Trade Centre, Near S...
# 1  Shop GF-18, ILD Trade Centre, Sector 47, Near ...
# 2  Opposite Audi Showroom, 5th Floor, 12th Square...
# 3  Urban Estate, Main Market, Phase 1, Dugri, Lud...
# 4  1st Floor, ARSS Mall, Opposite Jwalaheri, Pasc...
#
#                               Locality  Longitude  ...  Average_Cost_for_two  \
# 0    ILD Trade Centre Mall, Sohna Road  77.039220  ...                   800
# 1    ILD Trade Centre Mall, Sohna Road  77.039310  ...                   350
# 2  12th Square Building, Banjara Hills  78.437225  ...                  1500
# 3                A Hotel, Gurdev Nagar  75.842739  ...                   800
# 4             ARSS Mall, Paschim Vihar  77.101544  ...                   500
#
#              Currency  Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indian Rupees(Rs.)                  1                 Yes            2
# 1  Indian Rupees(Rs.)                  0                  No            1
# 2  Indian Rupees(Rs.)                  1                 Yes            3
# 3  Indian Rupees(Rs.)                  0                  No            2
# 4  Indian Rupees(Rs.)                  0                  No            2
#
#   Aggregate_rating  Rating_color  Rating_text Votes Country
# 0              2.7        Orange      Average    80   India
# 1              3.4        Orange      Average    16   India
# 2              4.3         Green    Very Good  3374   India
# 3              3.6        Yellow         Good    93   India
# 4              3.1        Orange      Average   117   India
#
# [5 rows x 22 columns]

# %%
# making a dataframe of rating restaurant
df = pd.DataFrame(Rest[['Country','City','Locality_Verbose','Cuisines_x','Count']])

# grouping the data by country code
country = Rest.sort_values(by='Count', ascending=False).groupby(['Country'], as_index=False).first()

con = pd.DataFrame(country[['Country','City','Locality','Cuisines_x','Count']])

# renaming the columns
con.columns= ['Country','City','Locality','Cuisines','Number of restaurants in the country']

# sorting the restaurants on the basis of the number of restaurants in the country
con1=con.sort_values('Number of restaurants in the country', ascending=False)

con1[:10]
final_con=con1.drop(con1.index[[7,10]])
final_con
# Out:
#           Country              City  \
# 3           India         New Delhi
# 14  United States           Dubuque
# 5     New Zealand   Wellington City
# 1          Brazil    Rio de Janeiro
# 6     Phillipines  Mandaluyong City
# 8       Singapore         Singapore
# 9    South Africa         Cape Town
# 11         Turkey            Ankara
# 12            UAE         Abu Dhabi
# 0       Australia     Victor Harbor
# 2          Canada  Vineland Station
# 4       Indonesia           Jakarta
# 7           Qatar              Doha
#
#                                            Locality       Cuisines  \
# 3                                   Connaught Place   North Indian
# 14                                          Dubuque       American
# 5                                            Te Aro           Cafe
# 1                                           Ipanema      Brazilian
# 6            SM Megamall, Ortigas, Mandaluyong City       Japanese
# 8                      Marina Centre, Downtown Core        Seafood
# 9                                       Green Point          Grill
# 11                                 Gazi Osman PaÅÙa  World Cuisine
# 12  Abu Dhabi Mall, Tourist Club Area  (Al Zahiyah)       American
# 0                                     Victor Harbor     Australian
# 2                                  Vineland Station          Pizza
# 4                                             Tebet        Western
# 7   The Westin Doha Hotel & Spa, Fereej Bin Mahmoud           Thai
#
#     Number of restaurants in the country
# 3                                     48
# 14                                     9
# 5                                      5
# 1                                      3
# 6                                      2
# 8                                      2
# 9                                      2
# 11                                     2
# 12                                     2
# 0                                      1
# 2                                      1
# 4                                      1
# 7                                      1

# %%
# Plotting number of Restaurants in the country

plt.figure(figsize=(16,6))
plt.bar(final_con['Cuisines'], final_con['Number of restaurants in the country'], color='m')
plt.title('Top Cuisines Served of different Restaurants on Each Country', fontsize=20)
plt.ylabel('Number of restaurants in the country', fontsize=16)
plt.xlabel('Different Cuisines', fontsize=16)
plt.xticks(rotation=45, fontsize=12)
plt.show()

# In our figure,
                # North Indian is the most prefered cuisine across the restaurant for each city.
                # Around 48 Restaurants allows  North Indian cuisine to customers, as customers also prefered this.
                # American is the 2nd prefered cuisine across the restaurant for each city.
                # Around 9 Restaurants allows this cuisine to serve with the customers.

# %% [markdown]
# ### What is the maximum and minimum number of cuisines that a restaurant serves?

# %%
BestRestaurants1.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  Average_Cost_for_two  \
# 0  106.821999 -6.196778        Italian, Continental                800000
# 1  106.818961 -6.203292  Asian, Indonesian, Western                800000
# 2  106.800144 -6.101298             Sushi, Japanese                500000
# 3  106.813400 -6.235241                    Japanese                450000
# 4  106.821023 -6.196270             French, Western                350000
#
#                  Currency  Has_Table_booking Has_Online_delivery  Price_range  \
# 0  Indonesian Rupiah(IDR)                  0                  No            3
# 1  Indonesian Rupiah(IDR)                  0                  No            3
# 2  Indonesian Rupiah(IDR)                  0                  No            3
# 3  Indonesian Rupiah(IDR)                  0                  No            3
# 4  Indonesian Rupiah(IDR)                  0                  No            3
#
#    Aggregate_rating Rating_color Rating_text  Votes    Country
# 0               4.1        Green   Very Good   1498  Indonesia
# 1               4.6   Dark Green   Excellent    873  Indonesia
# 2               4.9   Dark Green   Excellent    605  Indonesia
# 3               4.2        Green   Very Good    395  Indonesia
# 4               4.3        Green   Very Good    243  Indonesia

# %%
BestRestaurants1_new = BestRestaurants1.merge(final_con, left_on='Country', right_on='Country', how='outer')

# %%
BestRestaurants1_new.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code   City_x  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                       Locality_x                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                  Cuisines_x  ...  Price_range  \
# 0  106.821999 -6.196778        Italian, Continental  ...            3
# 1  106.818961 -6.203292  Asian, Indonesian, Western  ...            3
# 2  106.800144 -6.101298             Sushi, Japanese  ...            3
# 3  106.813400 -6.235241                    Japanese  ...            3
# 4  106.821023 -6.196270             French, Western  ...            3
#
#   Aggregate_rating  Rating_color Rating_text  Votes    Country   City_y  \
# 0              4.1         Green   Very Good   1498  Indonesia  Jakarta
# 1              4.6    Dark Green   Excellent    873  Indonesia  Jakarta
# 2              4.9    Dark Green   Excellent    605  Indonesia  Jakarta
# 3              4.2         Green   Very Good    395  Indonesia  Jakarta
# 4              4.3         Green   Very Good    243  Indonesia  Jakarta
#
#   Locality_y  Cuisines_y Number of restaurants in the country
# 0      Tebet     Western                                  1.0
# 1      Tebet     Western                                  1.0
# 2      Tebet     Western                                  1.0
# 3      Tebet     Western                                  1.0
# 4      Tebet     Western                                  1.0
#
# [5 rows x 24 columns]

# %%
print(BestRestaurants1.shape)
print(BestRestaurants1_new.shape)
# Out:
# (9551, 20)
# (9551, 24)

# %%
BestRestaurants1_new.drop(['City_y','Locality_y'], axis=1,inplace=True)

# %%
BestRestaurants1_new.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code   City_x  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                       Locality_x                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                  Cuisines_x  ...  Has_Table_booking  \
# 0  106.821999 -6.196778        Italian, Continental  ...                  0
# 1  106.818961 -6.203292  Asian, Indonesian, Western  ...                  0
# 2  106.800144 -6.101298             Sushi, Japanese  ...                  0
# 3  106.813400 -6.235241                    Japanese  ...                  0
# 4  106.821023 -6.196270             French, Western  ...                  0
#
#   Has_Online_delivery  Price_range Aggregate_rating  Rating_color  \
# 0                  No            3              4.1         Green
# 1                  No            3              4.6    Dark Green
# 2                  No            3              4.9    Dark Green
# 3                  No            3              4.2         Green
# 4                  No            3              4.3         Green
#
#    Rating_text Votes    Country  Cuisines_y  \
# 0    Very Good  1498  Indonesia     Western
# 1    Excellent   873  Indonesia     Western
# 2    Excellent   605  Indonesia     Western
# 3    Very Good   395  Indonesia     Western
# 4    Very Good   243  Indonesia     Western
#
#   Number of restaurants in the country
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
#
# [5 rows x 22 columns]

# %%
BestRestaurants1_new.rename(columns = {'City_x':'City','Locality_x':'Locality',
                                      'Cuisines_x':'Cuisines','Cuisines_y':'Cuisines_single'}, inplace=True)

# %%
BestRestaurants1_new.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  ...  Has_Table_booking  \
# 0  106.821999 -6.196778        Italian, Continental  ...                  0
# 1  106.818961 -6.203292  Asian, Indonesian, Western  ...                  0
# 2  106.800144 -6.101298             Sushi, Japanese  ...                  0
# 3  106.813400 -6.235241                    Japanese  ...                  0
# 4  106.821023 -6.196270             French, Western  ...                  0
#
#   Has_Online_delivery  Price_range Aggregate_rating  Rating_color  \
# 0                  No            3              4.1         Green
# 1                  No            3              4.6    Dark Green
# 2                  No            3              4.9    Dark Green
# 3                  No            3              4.2         Green
# 4                  No            3              4.3         Green
#
#    Rating_text Votes    Country  Cuisines_single  \
# 0    Very Good  1498  Indonesia          Western
# 1    Excellent   873  Indonesia          Western
# 2    Excellent   605  Indonesia          Western
# 3    Very Good   395  Indonesia          Western
# 4    Very Good   243  Indonesia          Western
#
#   Number of restaurants in the country
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
#
# [5 rows x 22 columns]

# %%
BestRestaurants1_new['Cuisines_single'].unique()
# Out:
# array([' Western', 'North Indian', 'Japanese', nan, ' Grill', 'Thai',
#        ' Seafood', 'American', 'Brazilian', 'World Cuisine', 'Cafe',
#        ' Australian', ' Pizza'], dtype=object)

# %%
BestRestaurants1_new.isna().sum()
# Out:
# Restaurant_ID                             0
# Restaurant_Name                           0
# Country_Code                              0
# City                                      0
# Address                                   0
# Locality                                  0
# Locality_Verbose                          0
# Longitude                                 0
# Latitude                                  0
# Cuisines                                  0
# Average_Cost_for_two                      0
# Currency                                  0
# Has_Table_booking                         0
# Has_Online_delivery                       0
# Price_range                               0
# Aggregate_rating                          0
# Rating_color                              0
# Rating_text                               0
# Votes                                     0
# Country                                   0
# Cuisines_single                         100
# Number of restaurants in the country    100
# dtype: int64

# %%
# Replacing Null values with mode of that column i.e. "North Indian"

BestRestaurants1_new['Cuisines_single'].fillna('North Indian', inplace=True)

# %%
BestRestaurants1_new['Number of restaurants in the country'].mean()
# Out:
# 44.444291609353506

# %%
# Replacing Null values with mean of that column i.e. "BestRestaurants1_new['Number of restaurants in the country'].mean()"

BestRestaurants1_new['Number of restaurants in the country'].fillna(BestRestaurants1_new['Number of restaurants in the country'].mean(),
                                                                   inplace=True)

# %%
BestRestaurants1_new.isna().sum()
# Out:
# Restaurant_ID                           0
# Restaurant_Name                         0
# Country_Code                            0
# City                                    0
# Address                                 0
# Locality                                0
# Locality_Verbose                        0
# Longitude                               0
# Latitude                                0
# Cuisines                                0
# Average_Cost_for_two                    0
# Currency                                0
# Has_Table_booking                       0
# Has_Online_delivery                     0
# Price_range                             0
# Aggregate_rating                        0
# Rating_color                            0
# Rating_text                             0
# Votes                                   0
# Country                                 0
# Cuisines_single                         0
# Number of restaurants in the country    0
# dtype: int64

# %%
rest_cuisine = pd.DataFrame(df_cuisines[['Restaurant_Name','City','Cuisine_1','Cuisine_2','Cuisine_3','Cuisine_4',
                                         'Cuisine_5','Cuisine_6','Cuisine_7','Cuisine_8']])

#stacking the columns
rest_cuisine_stack=pd.DataFrame(rest_cuisine.stack())  
rest_cuisine.head()
# Out:
#                Restaurant_Name     City Cuisine_1     Cuisine_2 Cuisine_3  \
# 0                         Skye  Jakarta   Italian   Continental       NaN
# 1     Satoo - Hotel Shangri-La  Jakarta     Asian    Indonesian   Western
# 2                   Sushi Masa  Jakarta     Sushi      Japanese       NaN
# 3               3 Wise Monkeys  Jakarta  Japanese           NaN       NaN
# 4  Avec Moi Restaurant and Bar  Jakarta    French       Western       NaN
#
#   Cuisine_4 Cuisine_5 Cuisine_6 Cuisine_7 Cuisine_8
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN

# %%
keys1 = [c for c in rest_cuisine  if c.startswith('Cuisine')]
b=pd.melt(rest_cuisine, id_vars='Restaurant_Name', value_vars=keys, value_name='Cuisines') 

#melting the stack into one row
max_rate1=pd.DataFrame(b.groupby(by=['Restaurant_Name','variable','Cuisines']).size().reset_index()) 

#find the highest restuarant in the city
max_rate1
del max_rate1['variable']
max_rate1.columns=['Restaurant_Name','Cuisines','Count']
max_rate1.head(20)
# Out:
#             Restaurant_Name       Cuisines  Count
# 0                     12212      Fast Food      1
# 1              Let's Burrrp        Chinese      1
# 2              Let's Burrrp   North Indian      1
# 3                       #45           Cafe      1
# 4              #Dilliwaala6   North Indian      1
# 5              #InstaFreeze      Ice Cream      1
# 6               #OFF Campus           Cafe      1
# 7               #OFF Campus    Continental      1
# 8               #OFF Campus        Italian      1
# 9               #OFF Campus      Fast Food      1
# 10             #Urban CafÌ©   North Indian      1
# 11             #Urban CafÌ©        Chinese      1
# 12             #Urban CafÌ©        Italian      1
# 13                 #hashtag           Cafe      1
# 14                   'Ohana       Hawaiian      1
# 15        10 Downing Street   North Indian      2
# 16        10 Downing Street        Chinese      2
# 17        10 To 10 In Delhi         Indian      1
# 18        10 To 10 In Delhi           Cafe      1
# 19  11th Avenue Cafe Bistro           Cafe      1

# %%
max_rate1.sort_values('Count',ascending=False)

#Cafe Coffee Day has the max number of cuisines and The least number of cuisines in a resaurant is 1.
# Out:
#               Restaurant_Name       Cuisines  Count
# 2479          Cafe Coffee Day           Cafe     83
# 4600           Domino's Pizza          Pizza     79
# 4601           Domino's Pizza      Fast Food     78
# 12989                  Subway   Healthy Food     63
# 12988                  Subway          Salad     63
# ...                       ...            ...    ...
# 5570             Gabbar Meals        Mughlai      1
# 5571   Gabbar's Bar & Kitchen   North Indian      1
# 5572   Gabbar's Bar & Kitchen        Chinese      1
# 5573   Gabbar's Bar & Kitchen        Mexican      1
# 15967     Ìàukura€Ùa Sofras€±         Izgara      1
#
# [15968 rows x 3 columns]

# %% [markdown]
# ### Also, which is the most served cuisine across the restaurant for each city?

# %%
BestRestaurants1.groupby(['Cuisines','Restaurant_Name','City'])['Restaurant_Name'].count().nlargest(20)
# Out:
# Cuisines                                  Restaurant_Name       City
# Cafe                                      Cafe Coffee Day       New Delhi    57
# Pizza, Fast Food                          Domino's Pizza        New Delhi    55
# American, Fast Food, Salad, Healthy Food  Subway                New Delhi    38
# Raw Meats, North Indian, Fast Food        Green Chick Chop      New Delhi    35
# Fast Food, Burger                         McDonald's            New Delhi    33
# Beverages                                 Keventers             New Delhi    24
# Ice Cream, Desserts                       Giani                 New Delhi    24
#                                           Giani's               New Delhi    17
# Cafe                                      Cafe Coffee Day       Noida        13
# Ice Cream                                 Baskin Robbins        New Delhi    13
# Raw Meats, Fast Food                      Republic of Chicken   New Delhi    13
# Fast Food, North Indian                   Twenty Four Seven     New Delhi    12
# Italian, Pizza, Fast Food                 Pizza Hut             New Delhi    12
#                                           Pizza Hut Delivery    New Delhi    12
# American, Fast Food, Salad, Healthy Food  Subway                Gurgaon      11
#                                                                 Noida        11
# Cafe                                      Cafe Coffee Day       Gurgaon      11
# Fast Food                                 34, Chowringhee Lane  New Delhi    11
# Pizza, Fast Food                          Domino's Pizza        Noida        11
# Burger, Desserts, Fast Food               Dunkin' Donuts        New Delhi    10
# Name: Restaurant_Name, dtype: int64

# %%
Cuisines_count = BestRestaurants1_new.groupby(['Restaurant_Name','City','Cuisines_single']).agg(Count=('Cuisines_single','count'))
Cuisines_count
# Out:
#                                                       Count
# Restaurant_Name      City            Cuisines_single
# 12212                Nashik          North Indian         1
#  Let's Burrrp        Noida           North Indian         1
# #45                  Mangalore       North Indian         1
# #Dilliwaala6         Puducherry      North Indian         1
# #InstaFreeze         New Delhi       North Indian         1
# ...                                                     ...
# t Lounge by Dilmah   New Delhi       North Indian         1
# tashas               Cape Town        Grill               1
# wagamama             Wellington City Cafe                 1
# {Niche} - Cafe & Bar New Delhi       North Indian         1
# Ìàukura€Ùa Sofras€±  Ankara          World Cuisine        1
#
# [7974 rows x 1 columns]

# %%
Cuisines_count.sort_values(by='Count', ascending=False)[0:20]

# North Indian Cuisines is most served cuisines accross Restaurants on each city
# Out:
#                                                 Count
# Restaurant_Name      City      Cuisines_single
# Cafe Coffee Day      New Delhi North Indian        57
# Domino's Pizza       New Delhi North Indian        55
# Subway               New Delhi North Indian        38
# Green Chick Chop     New Delhi North Indian        37
# McDonald's           New Delhi North Indian        33
# Giani                New Delhi North Indian        24
# Keventers            New Delhi North Indian        24
# Giani's              New Delhi North Indian        17
# Aggarwal Sweets      New Delhi North Indian        14
# Wah Ji Wah           New Delhi North Indian        14
# Twenty Four Seven    New Delhi North Indian        13
# Pizza Hut Delivery   New Delhi North Indian        13
# Baskin Robbins       New Delhi North Indian        13
# Republic of Chicken  New Delhi North Indian        13
# Sagar Ratna          New Delhi North Indian        13
# Cafe Coffee Day      Noida     North Indian        13
# Pizza Hut            New Delhi North Indian        12
# 34, Chowringhee Lane New Delhi North Indian        12
# Subway               Gurgaon   North Indian        11
# Cafe Coffee Day      Gurgaon   North Indian        11

# %% [markdown]
# ### What is the distribution cost across the restaurants?

# %%
BestRestaurants1_new.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  ...  Has_Table_booking  \
# 0  106.821999 -6.196778        Italian, Continental  ...                  0
# 1  106.818961 -6.203292  Asian, Indonesian, Western  ...                  0
# 2  106.800144 -6.101298             Sushi, Japanese  ...                  0
# 3  106.813400 -6.235241                    Japanese  ...                  0
# 4  106.821023 -6.196270             French, Western  ...                  0
#
#   Has_Online_delivery  Price_range Aggregate_rating  Rating_color  \
# 0                  No            3              4.1         Green
# 1                  No            3              4.6    Dark Green
# 2                  No            3              4.9    Dark Green
# 3                  No            3              4.2         Green
# 4                  No            3              4.3         Green
#
#    Rating_text Votes    Country  Cuisines_single  \
# 0    Very Good  1498  Indonesia          Western
# 1    Excellent   873  Indonesia          Western
# 2    Excellent   605  Indonesia          Western
# 3    Very Good   395  Indonesia          Western
# 4    Very Good   243  Indonesia          Western
#
#   Number of restaurants in the country
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
#
# [5 rows x 22 columns]

# %%
BestRestaurants1_new.columns
# Out:
# Index(['Restaurant_ID', 'Restaurant_Name', 'Country_Code', 'City', 'Address',
#        'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Price_range', 'Aggregate_rating',
#        'Rating_color', 'Rating_text', 'Votes', 'Country', 'Cuisines_single',
#        'Number of restaurants in the country'],
#       dtype='object')

# %%
BestRestaurants1_new['Currency'].unique()
# Out:
# array(['Indonesian Rupiah(IDR)', 'Indian Rupees(Rs.)', 'Botswana Pula(P)',
#        'Sri Lankan Rupee(LKR)', 'Rand(R)', 'Qatari Rial(QR)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Brazilian Real(R$)', 'Turkish Lira(TL)',
#        'Pounds(å£)', 'NewZealand($)'], dtype=object)

# %%
# Now we define a function, so that we can standalized currency  with different countries.

def std_rupee(currency, cost):
    if currency == 'Indonesian Rupiah(IDR)':
        return cost*194.24
    elif currency == 'Botswana Pula(P)':
        return cost*0.15
    elif currency == 'Sri Lankan Rupee(LKR)':
        return cost*2.67
    elif currency == 'Rand(R)':
        return cost*0.19
    elif currency == 'Qatari Rial(QR)':
        return cost*0.049
    elif currency == 'Dollar($)':
        return cost*0.013
    elif currency == 'Emirati Diram(AED)':
        return cost*0.049
    elif currency == 'Brazilian Real(R$)':
        return cost*0.069
    elif currency == 'Turkish Lira(TL)':
        return cost*0.11
    elif currency == 'Pounds(å£)':
        return cost*0.0097
    elif currency == 'NewZealand($)':
        return cost*0.019
    else:
        return cost

# %%
std_rupee('Indonesian Rupiah(IDR)',800000)
# Out:
# 155392000.0

# %%
#BestRestaurants1_new['standalized_inr']=[(map(lambda x,y: std_rupee(x,y),x,y) for x,y in BestRestaurants1_new[['Currency','Average_Cost_for_two']])]

# %%
BestRestaurants1_new.loc[0,'Currency']
# Out:
# 'Indonesian Rupiah(IDR)'

# %%
#for i in np.arange(len(BestRestaurants1_new)):
#                   BestRestaurants1_new.loc[i,'new_col'] = std_rupee(BestRestaurants1_new.loc[i,'Currency'],BestRestaurants1_new.loc[i,'Average_Cost_for_two'])

# %%
for i in np.arange(len(BestRestaurants1_new)):
                     BestRestaurants1_new.loc[i,'Standalized_Cost'] = std_rupee(BestRestaurants1_new.loc[i,'Currency'],BestRestaurants1_new.loc[i,'Average_Cost_for_two'])

# %%
BestRestaurants1_new.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  ...  Has_Online_delivery  \
# 0  106.821999 -6.196778        Italian, Continental  ...                   No
# 1  106.818961 -6.203292  Asian, Indonesian, Western  ...                   No
# 2  106.800144 -6.101298             Sushi, Japanese  ...                   No
# 3  106.813400 -6.235241                    Japanese  ...                   No
# 4  106.821023 -6.196270             French, Western  ...                   No
#
#   Price_range  Aggregate_rating Rating_color  Rating_text  Votes    Country  \
# 0           3               4.1        Green    Very Good   1498  Indonesia
# 1           3               4.6   Dark Green    Excellent    873  Indonesia
# 2           3               4.9   Dark Green    Excellent    605  Indonesia
# 3           3               4.2        Green    Very Good    395  Indonesia
# 4           3               4.3        Green    Very Good    243  Indonesia
#
#   Cuisines_single  Number of restaurants in the country Standalized_Cost
# 0         Western                                   1.0      155392000.0
# 1         Western                                   1.0      155392000.0
# 2         Western                                   1.0       97120000.0
# 3         Western                                   1.0       87408000.0
# 4         Western                                   1.0       67984000.0
#
# [5 rows x 23 columns]

# %%
#BestRestaurants1_new['new_col'] = lambda x: std_rupee(BestRestaurants1_new.iloc(x,'Currency'),
#                                               BestRestaurants1_new.iloc(x,'Average_Cost_for_two'))

# %%
BestRestaurants1_new.head(2)
# Out:
#    Restaurant_ID           Restaurant_Name  Country_Code     City  \
# 0        7402935                      Skye            94  Jakarta
# 1        7410290  Satoo - Hotel Shangri-La            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
#
#     Longitude  Latitude                    Cuisines  ...  Has_Online_delivery  \
# 0  106.821999 -6.196778        Italian, Continental  ...                   No
# 1  106.818961 -6.203292  Asian, Indonesian, Western  ...                   No
#
#   Price_range  Aggregate_rating Rating_color  Rating_text  Votes    Country  \
# 0           3               4.1        Green    Very Good   1498  Indonesia
# 1           3               4.6   Dark Green    Excellent    873  Indonesia
#
#   Cuisines_single  Number of restaurants in the country Standalized_Cost
# 0         Western                                   1.0      155392000.0
# 1         Western                                   1.0      155392000.0
#
# [2 rows x 23 columns]

# %% [markdown]
# ### How ratings are distributed among the various factors?

# %%
BestRestaurants1_new.head()
# Out:
#    Restaurant_ID              Restaurant_Name  Country_Code     City  \
# 0        7402935                         Skye            94  Jakarta
# 1        7410290     Satoo - Hotel Shangri-La            94  Jakarta
# 2        7420899                   Sushi Masa            94  Jakarta
# 3        7421967               3 Wise Monkeys            94  Jakarta
# 4        7422489  Avec Moi Restaurant and Bar            94  Jakarta
#
#                                              Address  \
# 0  Menara BCA, Lantai 56, Jl. MH. Thamrin, Thamri...
# 1               Hotel Shangri-La, Jl. Jend. Sudirman
# 2                   Jl. Tuna Raya No. 5, Penjaringan
# 3                Jl. Suryo No. 26, Senopati, Jakarta
# 4  Gedung PIC, Jl. Teluk Betung 43, Thamrin, Jakarta
#
#                         Locality                        Locality_Verbose  \
# 0  Grand Indonesia Mall, Thamrin  Grand Indonesia Mall, Thamrin, Jakarta
# 1     Hotel Shangri-La, Sudirman     Hotel Shangri-La, Sudirman, Jakarta
# 2                    Penjaringan                    Penjaringan, Jakarta
# 3                       Senopati                       Senopati, Jakarta
# 4                        Thamrin                        Thamrin, Jakarta
#
#     Longitude  Latitude                    Cuisines  ...  Has_Online_delivery  \
# 0  106.821999 -6.196778        Italian, Continental  ...                   No
# 1  106.818961 -6.203292  Asian, Indonesian, Western  ...                   No
# 2  106.800144 -6.101298             Sushi, Japanese  ...                   No
# 3  106.813400 -6.235241                    Japanese  ...                   No
# 4  106.821023 -6.196270             French, Western  ...                   No
#
#   Price_range  Aggregate_rating Rating_color  Rating_text  Votes    Country  \
# 0           3               4.1        Green    Very Good   1498  Indonesia
# 1           3               4.6   Dark Green    Excellent    873  Indonesia
# 2           3               4.9   Dark Green    Excellent    605  Indonesia
# 3           3               4.2        Green    Very Good    395  Indonesia
# 4           3               4.3        Green    Very Good    243  Indonesia
#
#   Cuisines_single  Number of restaurants in the country Standalized_Cost
# 0         Western                                   1.0      155392000.0
# 1         Western                                   1.0      155392000.0
# 2         Western                                   1.0       97120000.0
# 3         Western                                   1.0       87408000.0
# 4         Western                                   1.0       67984000.0
#
# [5 rows x 23 columns]

# %%
plt.figure(figsize=(16,6))
sns.histplot(BestRestaurants1['Aggregate_rating'], color='purple')
plt.title("Aggregate Ratings with Frequency", fontsize=18)
plt.ylabel("Frequency", fontsize=14)
plt.xlabel("Aggregate Rating", fontsize=14)
plt.show()

# there are many restaurants which has very low ratings nearly zero.
# most of the rating lies between 2 to 5.
# nearly rating 3, count is quite higher i.e around 800 or 900.
# between rating 3 to 4, rating count are quite good. But after 5 count of rating started falling again. 
# Here, we can conclude that customer are most likely to give rating around 3 to 4, and
# average no. of people has given rating blow 3 and above 4.

# %%
# Highest Rating Restaurants
max_rate = BestRestaurants1.sort_values(by='Aggregate_rating', ascending=False).groupby(['Country','City'],
                                                                                       as_index=False).first()

# %%
# Lowest Rating Restaurants
min_rate = BestRestaurants1.sort_values(by='Aggregate_rating', ascending=False).groupby(['Country','City'],
                                                                                       as_index=False).last()

# %%
# New dataframe created for high rated restaurants

df_max = max_rate[['Country','City','Restaurant_Name','Aggregate_rating']]


# New dataframe created for low rated restaurants
df_min = min_rate[['Country','City','Restaurant_Name','Aggregate_rating']]

# %%
# Merging 2 dataframes into a single dataframe

rating = df_max.merge(df_min, left_on='City', right_on='City',how='inner')
rating
# Out:
#          Country_x            City                         Restaurant_Name_x  \
# 0        Australia        Armidale                           Whitebull Hotel
# 1        Australia        Balingup                         Taste of Balingup
# 2        Australia      Beechworth                       Bridge Road Brewers
# 3        Australia     Dicky Beach                         The Giggling Goat
# 4        Australia    East Ballina                         The Belle General
# ..             ...             ...                                       ...
# 136  United States        Valdosta                          Smok'n Pig B-B-Q
# 137  United States        Vernonia                           Blue House Cafe
# 138  United States        Waterloo                   Four Queens Dairy Cream
# 139  United States         Weirton  Theo Yianni's Authentic Greek Restaurant
# 140  United States  Winchester Bay                 Fishpatrick's Crabby Cafe
#
#      Aggregate_rating_x      Country_y  \
# 0                   3.5      Australia
# 1                   3.2      Australia
# 2                   4.6      Australia
# 3                   3.6      Australia
# 4                   4.1      Australia
# ..                  ...            ...
# 136                 4.1  United States
# 137                 4.3  United States
# 138                 3.9  United States
# 139                 3.9  United States
# 140                 3.2  United States
#
#                             Restaurant_Name_y  Aggregate_rating_y
# 0                             Whitebull Hotel                 3.5
# 1                           Taste of Balingup                 3.2
# 2                         Bridge Road Brewers                 4.6
# 3                           The Giggling Goat                 3.6
# 4                           The Belle General                 4.1
# ..                                        ...                 ...
# 136               El Toreo Mexican Restaurant                 3.1
# 137                           Blue House Cafe                 4.3
# 138               Masala Grill & Coffee House                 3.2
# 139  Theo Yianni's Authentic Greek Restaurant                 3.9
# 140                 Fishpatrick's Crabby Cafe                 3.2
#
# [141 rows x 7 columns]

# %%
# Here we have 2 country column, so we drop 1 column

rating.drop('Country_y', axis=1,inplace=True)

# %%
# changing the names of the columns

rating.columns = ['Country','City','Highest Rated Restaurant','Rating Max','Lowest Rated Restaurant','Rating Min']
rating.columns
# Out:
# Index(['Country', 'City', 'Highest Rated Restaurant', 'Rating Max',
#        'Lowest Rated Restaurant', 'Rating Min'],
#       dtype='object')

# %%
rating.head()
# Out:
#      Country          City Highest Rated Restaurant  Rating Max  \
# 0  Australia      Armidale          Whitebull Hotel         3.5
# 1  Australia      Balingup        Taste of Balingup         3.2
# 2  Australia    Beechworth      Bridge Road Brewers         4.6
# 3  Australia   Dicky Beach        The Giggling Goat         3.6
# 4  Australia  East Ballina        The Belle General         4.1
#
#   Lowest Rated Restaurant  Rating Min
# 0         Whitebull Hotel         3.5
# 1       Taste of Balingup         3.2
# 2     Bridge Road Brewers         4.6
# 3       The Giggling Goat         3.6
# 4       The Belle General         4.1

# %%
# Since India and USA has the most number of restaurants, 
# we will try to see the distribution of restaurants ratings for these two countries.

# storing the dataframe only for country 'India'
rating_India = rating[rating['Country']=='India']
rating_India.head()
# Out:
#    Country        City Highest Rated Restaurant  Rating Max  \
# 30   India        Agra          Sheroes Hangout         4.9
# 31   India   Ahmedabad                 Cryo Lab         4.6
# 32   India   Allahabad                   Eat On         3.7
# 33   India    Amritsar   Gurdas Ram Jalebi Wala         4.1
# 34   India  Aurangabad          Bhoj Restaurant         3.7
#
#                Lowest Rated Restaurant  Rating Min
# 30                The Charcoal Chimney         3.4
# 31  MoMo CafÌ© - Courtyard By Marriott         3.6
# 32                       Pind Balluchi         3.2
# 33                   The Yellow Chilli         3.4
# 34                      Domino's Pizza         3.1

# %%
# converting the series to list
city_i = rating_India['City'].tolist()

# converting the series to list
rate_max_i = rating_India['Rating Max'].tolist()

# converting the series to list
rate_min_i = rating_India['Rating Min'].tolist()

# converting the series to list
rest_name_high_i = rating_India['Highest Rated Restaurant'].tolist()

# converting the series to list
rest_name_low_i = rating_India['Lowest Rated Restaurant'].tolist()

# %%
# Plotting rating of cities in India using stached bar chart

plt.figure(figsize=(16,6))
w=0.5
plt.bar(city_i,rate_max_i,w,label="Highest Rated Restaurant", color='c')
plt.bar(city_i,rate_min_i,w,label="Lowest Rated Restaurant", color='g')
plt.title('Restaurants ratings of different cities in India [ Staked Bar Chart ]', fontsize=20)
plt.xlabel('Cities of India', fontsize=18)
plt.ylabel('Rating (Scale of 5)', fontsize=18)
plt.xticks(rotation=90, fontsize=14)
plt.legend(loc='upper right')
plt.show()

# %%
# Plotting rating of cities in India using grouped bar chart

plt.figure(figsize=(20,6))
w=0.4
x = city_i
bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
plt.bar(bar1,rate_max_i,w,label="Highest Rated Restaurant", color='g')
plt.bar(bar2,rate_min_i,w,label="Lowest Rated Restaurant", color='m')
plt.title('Restaurants ratings of different cities in India  [ Grouped Bar Chart ]', fontsize=20)
plt.xlabel('Cities of India', fontsize=18)
plt.ylabel('Rating (Scale of 5)', fontsize=18)
plt.xticks(bar1+w,x,rotation=90, fontsize=16)
plt.legend(loc='upper right',shadow=True,fancybox=True,borderpad=1)
plt.show()


# In our figure,
                # this is how high and low rated restaurants are arranged based on their rating. 
                # Faridabad, Ghazoabad, New Delhi and Noida have no lower rated Restaurants.
                # so we can above 4 cities are more profitable cities for Zomato for run their business.

# %%
# storing the dataframe only for country 'India'
rating_USA = rating[rating['Country']=='United States']
rating_USA.head()
# Out:
#            Country                    City       Highest Rated Restaurant  \
# 106  United States                  Albany  Guang Zhou Chinese Restaurant
# 107  United States                  Athens                      Sr. Sol 1
# 108  United States                 Augusta             Rae's Coastal Cafe
# 109  United States                   Boise  Flatbread Neapolitan Pizzeria
# 110  United States  Cedar Rapids/Iowa City        Shorts Burger and Shine
#
#      Rating Max      Lowest Rated Restaurant  Rating Min
# 106         3.9  Austin's BBQ and Oyster Bar         3.3
# 107         4.6                    The Grill         3.7
# 108         4.9           Sconyers Bar B Que         3.5
# 109         4.6         Chandlers Steakhouse         3.9
# 110         4.9               Bluebird Diner         3.6

# %%
# converting the series to list
city_u = rating_USA['City'].tolist()

# converting the series to list
rate_max_u = rating_USA['Rating Max'].tolist()

# converting the series to list
rate_min_u = rating_USA['Rating Min'].tolist()

# converting the series to list
rest_name_high_u = rating_USA['Highest Rated Restaurant'].tolist()

# converting the series to list
rest_name_low_u = rating_USA['Lowest Rated Restaurant'].tolist()

# %%
# plotting rating of cities in USA using stached bar chart

plt.figure(figsize=(20,8))
w=0.4
plt.bar(city_u, rate_max_u,w,label='Highest Rated Restaurant', color='r')
plt.bar(city_u, rate_min_u,w,bottom= rate_max_u,label='Lowest Rated Restaurant',color='c')
plt.title('Restaurants ratings of different cities in India [ Staked Bar Chart ]', fontsize=20)
plt.ylabel('Rating (Scale of 5)', fontsize=16)
plt.xlabel('Cities in USA', fontsize=16)
plt.xticks(rotation=90, fontsize=14)
plt.legend(loc='upper right')
plt.show()

# %%
# Plotting rating of cities in India using grouped bar chart

plt.figure(figsize=(20,6))
w=0.4
x = city_u
bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
plt.bar(bar1,rate_max_u,w,label="Highest Rated Restaurant", color='r')
plt.bar(bar2,rate_min_u,w,label="Lowest Rated Restaurant", color='b')
plt.title('Restaurants ratings of different cities in USA  [ Grouped Bar Chart ]', fontsize=20)
plt.xlabel('Cities of USA', fontsize=18)
plt.ylabel('Rating (Scale of 5)', fontsize=18)
plt.xticks(bar1+w,x,rotation=90, fontsize=16)
plt.legend(loc='upper right',shadow=True,fancybox=True,borderpad=1)
plt.show()

# In our figure,
                # this is how high and low rated restaurants are arranged based on their rating. 
                # Davenport, Pocatello have no lower rated Restaurants.
                # so we can above 2 cities are more profitable cities for Zomato for run their business.

# %% [markdown]
# ---

# %% [markdown]
# ### Explain the factors in the data that may have an effect on ratings.
# ### For example, number of cuisines, cost, delivery option, etc.

# %%
#BestRestaurants1_new.corr()

# %%
# creating a heatmap to know relation between variables

#plt.figure(figsize=(16,6))
#sns.heatmap(BestRestaurants1_new.corr(), cmap='coolwarm', center=0)
#plt.show()

# %%
# Download the file in Excel format
#BestRestaurants1_new.to_excel('data1(restaurants).xlsx', header=True, index=False)

# %% [markdown]
# ## TABLEAU

# %%
# Visualize the variables using Tableau to help user explore the data and 
# create a better understanding of the restaurants to identify 
# the ‘’star’’ restaurant

# Demonstrate the variables associated with each other and factors to build 
# a dashboard

# %%
## Tablau Public link of the whole tableau file

#'https://public.tableau.com/app/profile/soumya.kanti.bhar/viz/Project--IdentifyingandRecommendingBestRestaurants/BestRestaurantsDashboard?publish=yes'

# %% [markdown]
# ## Dashboard of Restaurants

# %% [markdown]
# ![Dashboard%28Restaurants%29%20-%20Copy.png](attachment:Dashboard%28Restaurants%29%20-%20Copy.png)
